# %%
import pandas as pd

# %%
dataset=pd.read_csv("Placement.csv")
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
dataset['ssc_p'].dtypes
# Out:
# dtype('float64')

# %%
for columnName in dataset.columns:
    print(columnName)
# Out:
# sl_no
# gender
# ssc_p
# ssc_b
# hsc_p
# hsc_b
# hsc_s
# degree_p
# degree_t
# workex
# etest_p
# specialisation
# mba_p
# status
# salary

# %%
if(dataset["gender"].dtype=='O'):
    print("Qual")
else:
    print("Quan")
# Out:
# Qual

# %%
Quan=[]
Qual=[]
for columnName in dataset.columns:
    #print(columnName)
    if(dataset[columnName].dtype=='O'):
        #print("Qual")
        Qual.append(columnName)
    else:
        #print("Quan")
        Quan.append(columnName)

# %%
Quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
Qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
def QuanQual():
    Quan=[]
    Qual=[]
    for columnName in dataset.columns:
        print(columnName)
        if(dataset[columnName].dtypes=="O"):
            #print("Qual")
            Qual.append(columnName)
        else:
            #print("Quan")
            Quan.append(columnName)
    return Quan,Qual

# %%
Quan,Qual=QuanQual()
# Out:
# sl_no
# gender
# ssc_p
# ssc_b
# hsc_p
# hsc_b
# hsc_s
# degree_p
# degree_t
# workex
# etest_p
# specialisation
# mba_p
# status
# salary

# %%
Quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
Qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %% [markdown]
# # we have to split the qualitative and quantitative
# #qual is object
# #quan is numerical

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# #central tendency

# %%
dataset["ssc_p"].mean()
# Out:
# 67.30339534883721

# %%
dataset["ssc_p"].median()
# Out:
# 67.0

# %%
dataset["ssc_p"].mode()[0]
# Out:
# 62.0

# %%
dataset.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
descriptive=pd.DataFrame(index=["mean","median","mode"],columns=Quan)

# %%
descriptive
# Out:
#        sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# mean     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# median   NaN   NaN   NaN      NaN     NaN   NaN    NaN
# mode     NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
descriptive["sl_no"]["median"]=0

# %%
descriptive=pd.DataFrame(index=["mean","median","mode"],columns=Quan)
for columnName in Quan:
    descriptive[columnName]["mean"]=dataset[columnName].mean()
    descriptive[columnName]["median"]=dataset[columnName].median()
    descriptive[columnName]["mode"]=dataset[columnName].mode()[0]

# %%
descriptive
# Out:
#         sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# mean    108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# median  108.0       67.0       65.0       66.0       71.0       62.0
# mode        1       62.0       63.0       65.0       60.0       56.7
#
#                salary
# mean    288655.405405
# median       265000.0
# mode         300000.0

# %% [raw]
# #mean:it is average(summing up all the values in data set and dividingthe sum by the total number of observation)
# #median: it is the middle value of data in ascending or descending order,it can be also odd or even
# #mode: it the value that appears most frequently in dataset
# it is a placement data of students who are placed and their salary, the data set cotantains sl_no, gender,ssc_p,ssc_b,hsc_p,hsc_b,hsc_s,degree_p,degree_t,workex,etest_p,specialisation,mba_p,status, salary.
# # Based on this dataset student performed average in ssc_p,hsc_p,degree_p, they got average marks
# #And slightly improved their performance in etest_p ,in this test they scored above average marks
# #Again the students  performed average in mba_p so based on this average they can analyse their salary
# # IN ssc they scoed 62 repeatedly ,in hsc they scoed 63 repeatedly,in degree_p they scoed 65 repeatedly,in etest_p they scoed 60 repeatedly,in mba_p they scoed 63 repeatedly so their repeated salary is 300000

# %%
import numpy as np

# %%
np.percentile(dataset["ssc_p"],100)
# Out:
# 89.4

# %%
descriptive=pd.DataFrame(index=["mean","median","mode","Q1:25%","Q2:50%","Q3:75%","Q4:100%"],columns=Quan)
for columnName in Quan:
    descriptive[columnName]["mean"]=dataset[columnName].mean()
    descriptive[columnName]["median"]=dataset[columnName].median()
    descriptive[columnName]["mode"]=dataset[columnName].mode()[0]
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]

# %%
descriptive
# Out:
#          sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# mean     108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# median   108.0       67.0       65.0       66.0       71.0       62.0
# mode         1       62.0       63.0       65.0       60.0       56.7
# Q1:25%    54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%   108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%   161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100%  215.0       89.4       97.7       91.0       98.0      77.89
#
#                 salary
# mean     288655.405405
# median        265000.0
# mode          300000.0
# Q1:25%        240000.0
# Q2:50%        265000.0
# Q3:75%        300000.0
# Q4:100%       940000.0

# %% [raw]
# #percentile
# it is used to understand the distribution of data, take the certain percentage and compare
# Eg ssc_p : in this Q2 is incresed 7% compare to Q1
#            in this Q3 is incresed 8% compare to Q2,in this Q3 is incresed 15% compare to Q1
#            in this Q4 is incresed 14% compare to Q3,in this Q4 is incresed 22% compare to Q2,in this Q4 is incresed 29% compare to Q1

# %%
descriptive=pd.DataFrame(index=["mean","median","mode","Q1:25%","Q2:50%","Q3:75%","Q4:100%",
                               "IQR",'1.5rule',"lesser","greater","min","max"],columns=Quan)
for columnName in Quan:
    descriptive[columnName]["mean"]=dataset[columnName].mean()
    descriptive[columnName]["median"]=dataset[columnName].median()
    descriptive[columnName]["mode"]=dataset[columnName].mode()[0]
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
    descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]-  descriptive[columnName]["Q1:25%"]
    descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]
    descriptive[columnName]["lesser"]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5rule"]
    descriptive[columnName]["greater"]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"]
    descriptive[columnName]["min"]=dataset[columnName].min()
    descriptive[columnName]["max"]=dataset[columnName].max()

# %%
descriptive
# Out:
#          sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# mean     108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# median   108.0       67.0       65.0       66.0       71.0       62.0
# mode         1       62.0       63.0       65.0       60.0       56.7
# Q1:25%    54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%   108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%   161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100%  215.0       89.4       97.7       91.0       98.0      77.89
# IQR      107.0       15.1       12.1       11.0       23.5       8.31
# 1.5rule  160.5      22.65      18.15       16.5      35.25     12.465
# lesser  -106.0      37.95      42.75       44.5      24.75      45.48
# greater  322.0      98.35      91.15       88.5     118.75      78.72
# min          1      40.89       37.0       50.0       50.0      51.21
# ...

# %% [markdown]
# IQR : it is used to replace the outlier
# IQR=Q3-Q1
# LESSER=Q1-1.5*IQR
# GREATER=Q3+1.5*IQR
# IN THIS THE MINMUM VALUES IS GREATER THAN LESSER EXCEPT HSC_P
# OUTLIER PRESENT IN HSC_p

# %%
descriptive["hsc_p"]["min"]<descriptive["hsc_p"]["lesser"]
descriptive["hsc_p"]["max"]>descriptive["hsc_p"]["greater"]
# Out:
# True

# %%
lesser=[]
greater=[]
for columnName in Quan:
    if(descriptive[columnName]["min"]<descriptive[columnName]["lesser"]):
        lesser.append(columnName)
    if(descriptive[columnName]["max"]>descriptive[columnName]["greater"]):
         greater.append(columnName)

# %%
lesser
# Out:
# ['hsc_p']

# %%
greater
# Out:
# ['hsc_p', 'degree_p', 'salary']

# %%
for columnName in lesser:
    dataset[columnName][dataset[columnName]<descriptive[columnName]["lesser"]]=descriptive[columnName]["lesser"]
for columnName in greater:
    dataset[columnName][dataset[columnName]>descriptive[columnName]["greater"]]=descriptive[columnName]["greater"]
# Out:
# C:\Users\POOJA\AppData\Local\Temp\ipykernel_30824\494802273.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[columnName][dataset[columnName]<descriptive[columnName]["lesser"]]=descriptive[columnName]["lesser"]
# C:\Users\POOJA\AppData\Local\Temp\ipykernel_30824\494802273.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[columnName][dataset[columnName]>descriptive[columnName]["greater"]]=descriptive[columnName]["greater"]
# C:\Users\POOJA\AppData\Local\Temp\ipykernel_30824\494802273.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
descriptive=pd.DataFrame(index=["mean","median","mode","Q1:25%","Q2:50%","Q3:75%","Q4:100%",
                               "IQR",'1.5rule',"lesser","greater","min","max"],columns=Quan)
for columnName in Quan:
    descriptive[columnName]["mean"]=dataset[columnName].mean()
    descriptive[columnName]["median"]=dataset[columnName].median()
    descriptive[columnName]["mode"]=dataset[columnName].mode()[0]
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
    descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]-  descriptive[columnName]["Q1:25%"]
    descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]
    descriptive[columnName]["lesser"]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5rule"]
    descriptive[columnName]["greater"]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"]
    descriptive[columnName]["min"]=dataset[columnName].min()
    descriptive[columnName]["max"]=dataset[columnName].max()

# %%
descriptive
# Out:
#          sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# mean     108.0  67.303395  66.334744  66.358558  72.100558  62.278186
# median   108.0       67.0       65.0       66.0       71.0       62.0
# mode         1       62.0       63.0       65.0       60.0       56.7
# Q1:25%    54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%   108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%   161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100%  215.0       89.4      91.15       88.5       98.0      77.89
# IQR      107.0       15.1       12.1       11.0       23.5       8.31
# 1.5rule  160.5      22.65      18.15       16.5      35.25     12.465
# lesser  -106.0      37.95      42.75       44.5      24.75      45.48
# greater  322.0      98.35      91.15       88.5     118.75      78.72
# min          1      40.89      42.75       50.0       50.0      51.21
# ...

# %%
lesser=[]
greater=[]
for columnName in Quan:
    if(descriptive[columnName]["min"]<descriptive[columnName]["lesser"]):
        lesser.append(columnName)
    if(descriptive[columnName]["max"]>descriptive[columnName]["greater"]):
         greater.append(columnName)

# %%
lesser
# Out:
# []

# %%
greater
# Out:
# []

# %%
dataset["ssc_p"].value_counts()
# Out:
# ssc_p
# 62.00    11
# 63.00    10
# 67.00     9
# 52.00     9
# 73.00     9
#          ..
# 69.70     1
# 80.92     1
# 83.00     1
# 86.50     1
# 80.60     1
# Name: count, Length: 103, dtype: int64

# %%
freqTable=pd.DataFrame(columns=["unique_values","frequency","relative frequency","cumsum"])

# %%
freqTable
# Out:
# Empty DataFrame
# Columns: [unique_values, frequency, relative frequency, cumsum]
# Index: []

# %%
freqTable["unique_values"]=dataset["ssc_p"].value_counts().index
freqTable["frequency"]=dataset["ssc_p"].value_counts().values
freqTable["relative frequency"]=(freqTable["frequency"]/103)
freqTable["cusum"]=freqTable["relative frequency"].cumsum()

# %%
def freqTable(columnName,dataset):
    freqTable=pd.DataFrame(columns=["unique_values","frequency","relative frequency","cumsum"])
    freqTable["unique_values"]=dataset[columnName].value_counts().index
    freqTable["frequency"]=dataset[columnName].value_counts().values
    freqTable["relative frequency"]=(freqTable["frequency"]/103)
    freqTable["cumsum"]=freqTable["relative frequency"].cumsum()
    return freqTable

# %% [markdown]
# #frequency is count (no.of times a particular value appers in dataset)
# #relative frequency is percentage of times a specific value occurs relative to the total number of observation in dataset(it is
# calculated by frequency value divided by total no of value)
# #cummilative frequeny is accumulation of frequency up to certain point by adding relative freqyency

# %%
freqTable(columnName,dataset)
# Out:
#     unique_values  frequency  relative frequency    cumsum
# 0        300000.0         22            0.213592  0.213592
# 1        250000.0         18            0.174757  0.388350
# 2        390000.0         15            0.145631  0.533981
# 3        240000.0         15            0.145631  0.679612
# 4        260000.0          7            0.067961  0.747573
# 5        200000.0          6            0.058252  0.805825
# 6        265000.0          6            0.058252  0.864078
# 7        360000.0          6            0.058252  0.922330
# 8        275000.0          5            0.048544  0.970874
# 9        220000.0          5            0.048544  1.019417
# 10       270000.0          4            0.038835  1.058252
# 11       210000.0          4            0.038835  1.097087
# 12       350000.0          3            0.029126  1.126214
# 13       216000.0          3            0.029126  1.155340
# 14       204000.0          2            0.019417  1.174757
# ...

# %%
def Univariate(dataset,Quan):
    descriptive=pd.DataFrame(index=["mean","median","mode","Q1:25%","Q2:50%",
                                    "Q3:75%","Q4:100%", "IQR",'1.5rule',"lesser","greater","min","max"],columns=Quan)
    for columnName in Quan:
        descriptive[columnName]["mean"]=dataset[columnName].mean()
        descriptive[columnName]["median"]=dataset[columnName].median()
        descriptive[columnName]["mode"]=dataset[columnName].mode()[0]
        descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
        descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
        descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
        descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
        descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]
        descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]
        descriptive[columnName]["lesser"]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5rule"]
        descriptive[columnName]["greater"]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"]
        descriptive[columnName]["min"]=dataset[columnName].min()
        descriptive[columnName]["max"]=dataset[columnName].max()
    return descriptive

# %%
 Univariate(dataset,Quan)
# Out:
#          sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# mean     108.0  67.303395  66.334744  66.358558  72.100558  62.278186
# median   108.0       67.0       65.0       66.0       71.0       62.0
# mode         1       62.0       63.0       65.0       60.0       56.7
# Q1:25%    54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%   108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%   161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100%  215.0       89.4      91.15       88.5       98.0      77.89
# IQR      107.0       15.1       12.1       11.0       23.5       8.31
# 1.5rule  160.5      22.65      18.15       16.5      35.25     12.465
# lesser  -106.0      37.95      42.75       44.5      24.75      45.48
# greater  322.0      98.35      91.15       88.5     118.75      78.72
# min          1      40.89      42.75       50.0       50.0      51.21
# ...

# %%
dataset["ssc_p"].skew()
# Out:
# -0.13264949031456927

# %%
dataset["ssc_p"].kurtosis()
# Out:
# -0.6075102066986688

# %%
def Univariate(dataset,Quan):
    descriptive=pd.DataFrame(index=["mean","median","mode","Q1:25%","Q2:50%",
                                    "Q3:75%","Q4:100%", "IQR",'1.5rule',"lesser","greater",
                                    "min","max","kurtosis","skew"],columns=Quan)
    for columnName in Quan:
        descriptive[columnName]["mean"]=dataset[columnName].mean()
        descriptive[columnName]["median"]=dataset[columnName].median()
        descriptive[columnName]["mode"]=dataset[columnName].mode()[0]
        descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
        descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
        descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
        descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
        descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]
        descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]
        descriptive[columnName]["lesser"]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5rule"]
        descriptive[columnName]["greater"]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"]
        descriptive[columnName]["min"]=dataset[columnName].min()
        descriptive[columnName]["max"]=dataset[columnName].max()
        descriptive[columnName]["kurtosis"]=dataset[columnName].kurtosis()
        descriptive[columnName]["skew"]=dataset[columnName].skew()
    return descriptive

# %%
 Univariate(dataset,Quan)
# Out:
#           sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# mean      108.0  67.303395  66.334744  66.358558  72.100558  62.278186
# median    108.0       67.0       65.0       66.0       71.0       62.0
# mode          1       62.0       63.0       65.0       60.0       56.7
# Q1:25%     54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%    108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%    161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100%   215.0       89.4      91.15       88.5       98.0      77.89
# IQR       107.0       15.1       12.1       11.0       23.5       8.31
# 1.5rule   160.5      22.65      18.15       16.5      35.25     12.465
# lesser   -106.0      37.95      42.75       44.5      24.75      45.48
# greater   322.0      98.35      91.15       88.5     118.75      78.72
# min           1      40.89      42.75       50.0       50.0      51.21
# ...

# %%
def Univariate(dataset,Quan):
    descriptive=pd.DataFrame(index=["mean","median","mode","Q1:25%","Q2:50%",
                                    "Q3:75%","Q4:100%", "IQR",'1.5rule',"lesser","greater",
                                    "min","max","kurtosis","skew","var","std"],columns=Quan)
    for columnName in Quan:
        descriptive[columnName]["mean"]=dataset[columnName].mean()
        descriptive[columnName]["median"]=dataset[columnName].median()
        descriptive[columnName]["mode"]=dataset[columnName].mode()[0]
        descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
        descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
        descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
        descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
        descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]
        descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]
        descriptive[columnName]["lesser"]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5rule"]
        descriptive[columnName]["greater"]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"]
        descriptive[columnName]["min"]=dataset[columnName].min()
        descriptive[columnName]["max"]=dataset[columnName].max()
        descriptive[columnName]["kurtosis"]=dataset[columnName].kurtosis()
        descriptive[columnName]["skew"]=dataset[columnName].skew()
        descriptive[columnName]["var"]=dataset[columnName].var()
        descriptive[columnName]["std"]=dataset[columnName].std()
    return descriptive

# %%
Univariate(dataset,Quan)
# Out:
#               sl_no       ssc_p       hsc_p   degree_p     etest_p      mba_p  \
# mean          108.0   67.303395   66.334744  66.358558   72.100558  62.278186
# median        108.0        67.0        65.0       66.0        71.0       62.0
# mode              1        62.0        63.0       65.0        60.0       56.7
# Q1:25%         54.5        60.6        60.9       61.0        60.0     57.945
# Q2:50%        108.0        67.0        65.0       66.0        71.0       62.0
# Q3:75%        161.5        75.7        73.0       72.0        83.5     66.255
# Q4:100%       215.0        89.4       91.15       88.5        98.0      77.89
# IQR           107.0        15.1        12.1       11.0        23.5       8.31
# 1.5rule       160.5       22.65       18.15       16.5       35.25     12.465
# lesser       -106.0       37.95       42.75       44.5       24.75      45.48
# greater       322.0       98.35       91.15       88.5      118.75      78.72
# ...

# %% [markdown]
# #kurtosis by this we can identify the dataset shape in graph
# #skewness is  the position in graph it is positive or negative or zero by this value
# #variance is varaiability (difference between)
# #standard deviation  is square rot of variance and provide measure of the average of the squared difference between each data point and mean
